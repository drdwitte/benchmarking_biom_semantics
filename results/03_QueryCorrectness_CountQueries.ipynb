# %%
import pandas as pd
from pandas import DataFrame, Series
#false positive warnings all the time:
pd.options.mode.chained_assignment = None

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

import numpy as np
import statistics

import os.path

# %%
#http://matplotlib.org/1.4.0/users/customizing.html

plt.style.use('ggplot')

mpl.rcParams['font.size'] = 18

### LINES
mpl.rcParams['lines.linewidth'] = '2.0'        # line width in points
mpl.rcParams['lines.marker']    = 'None'
mpl.rcParams['lines.markersize']=  '6'          # markersize, in points

###LEGEND
mpl.rcParams['legend.fontsize']='medium'

### GRIDS
mpl.rcParams['grid.color']='black'     # grid color
mpl.rcParams['grid.linestyle'] =':'    # dotted
mpl.rcParams['grid.linewidth']='0.5'   # in points
mpl.rcParams['grid.alpha']='1.0'       # transparency, between 0.0 and 1.0

### TICKS
mpl.rcParams['xtick.labelsize']="small"  # fontsize of the tick labels
mpl.rcParams['xtick.direction']="out"      # direction: in, out, or inout
mpl.rcParams['ytick.labelsize']="small"   # fontsize of the tick labels
mpl.rcParams['ytick.direction']="out"      # direction: in, out, or inout

### AXES
mpl.rcParams['axes.linewidth']  =  '1.0'    # edge linewidth
mpl.rcParams['axes.grid']       =  'True'   # display grid or not
mpl.rcParams['axes.titlesize']  =  'large'  # fontsize of the axes title
mpl.rcParams['axes.labelsize']  = 'large'  # fontsize of the x any y labels
mpl.rcParams['axes.facecolor']= 'white'     # axes background color

mpl.rcParams['figure.facecolor']= '1.0'     # figure facecolor; 0.75 is scalar gray

# %% [markdown]
# # Get the results of queries with only 1 result (typically count queries)
#
# * Preprocessing: the results directory contains gigabytes of data, let's filter out the files with only one line

# %% [markdown]
# ### Tryout

# %%
path = './query_results_analysis/SparqlResults_VirtuosoN1_64_Ontoforce_Optimized_VWall/'



sim_id = 'Vir_N1_64_Ont_Opt_VWall'

info_per_file = []

for filename in os.listdir(path):
    
    info = {}
    
    info['sim_id'] = sim_id
        
    removedextension = filename[:-4]
    spl = removedextension.split("_")
    info['query_hash'] = spl[0]
    info['query_timestamp'] = spl[1]
    
    full_path = path + filename
    
    first = None
    
    with open(full_path, 'r') as infile:
        c=0
        for line in infile:
            c+=1
            if c==1:
                first = line
    
    info['num_results'] = c
    info['first_result'] = first
    
    #print(info)
    info_per_file.append(info)    
        

        
df = pd.DataFrame(info_per_file)

# %%
df = df[df['num_results'] == 1]

grouped =  df.groupby(['query_hash'], as_index=False)
df_consistent =grouped.agg({'query_timestamp': np.size, 'first_result': pd.Series.nunique, 'num_results': pd.Series.nunique})
    
print(df_consistent.shape)

print(df_consistent[ (df_consistent['first_result'] > 1) | (df_consistent['num_results'] > 1)].shape)
# Out:
# (829, 4)
# (0, 4)

# %% [markdown]
# ## 1. Inter-thread consistency

# %%
def getQueryHashDataframe(path, sim_id):
    
    info_per_file = []

    for filename in os.listdir(path):
    
        info = {}

        info['sim_id'] = sim_id

        removedextension = filename[:-4]
        spl = removedextension.split("_")
        info['query_hash'] = spl[0]
        info['query_timestamp'] = spl[1]

        full_path = path + filename

        first = None

        with open(full_path, 'r') as infile:
            c=0
            for line in infile:
                c+=1
                if c==1:
                    first = line

        info['num_results'] = c
        info['first_result'] = first

        #print(info)
        info_per_file.append(info)    
        
               
    return pd.DataFrame(info_per_file)      

def getInconsitenciesBetweenThreads(df):
    df = df[df['num_results'] == 1]

    grouped =  df.groupby(['query_hash'], as_index=False)
    df_consistent =grouped.agg({'query_timestamp': np.size, 'first_result': pd.Series.nunique, 'num_results': pd.Series.nunique})
    

    return df_consistent[ (df_consistent['first_result'] > 1) | (df_consistent['num_results'] > 1)]

# %% [markdown]
# ### Query results are consistent between threads
#
# * print the dataframes holding the inconsistent results (there are none)

# %%
paths = [ './query_results_analysis/SparqlResults_VirtuosoN1_64_Ontoforce_Optimized_VWall/',
'./query_results_analysis/SparqlResults_VirtuosoN3_Ontoforce_AWS1/',
'./query_results_analysis/SparqlResults_VirtuosoN3_Ontoforce_AWS2/',
'./query_results_analysis/SparqlResults_Virtuoso_N1_32_Ontoforce_Optimized_VWall/',
'./query_results_analysis/SparqlResults_Virtuoso_N3_64_Ontoforce_Optimized_AWS3/']

sim_ids = ['Vir_N1_64_Ont_Opt_VWall', 'Vir_N3_64_Ont_Opt_AWS1', 'Vir_N3_64_Ont_Opt_AWS2', 'Vir_N1_32_Ont_Opt_VWall', \
           'Vir_N3_64_Ont_Opt_AWS3']

query_hash_dfs = []
for p,sim in zip(paths,sim_ids):
    df = getQueryHashDataframe(p,sim)
    query_hash_dfs.append(df)
    print(getInconsitenciesBetweenThreads(df))
# Out:
# Empty DataFrame
# Columns: [query_hash, query_timestamp, first_result, num_results]
# Index: []
# Empty DataFrame
# Columns: [query_hash, query_timestamp, first_result, num_results]
# Index: []
# Empty DataFrame
# Columns: [query_hash, query_timestamp, first_result, num_results]
# Index: []
# Empty DataFrame
# Columns: [query_hash, query_timestamp, first_result, num_results]
# Index: []
# Empty DataFrame
# Columns: [query_hash, query_timestamp, first_result, num_results]
# Index: []

# %% [markdown]
# ## 2. Results per simulation => dataframe

# %%
def cleanupQueryHashDF(df):
    df = df[df['num_results'] == 1]
    df_filtered = df.groupby('query_hash', as_index=False).first()
    df_filtered['first_result'] = df_filtered['first_result'].apply(lambda r: r.strip())
    return df_filtered[['sim_id', 'query_hash', 'first_result']]

# %%
dfs = [cleanupQueryHashDF(df) for df in query_hash_dfs]

df_all = pd.concat(dfs)

df_hash_sorted = df_all.sort_values(['query_hash'])
df_hash_sorted.to_csv('./queryhashanalysis/CountQueryConsistency.csv', sep='\t', index=False)
df_hash_sorted
# Out:
#                       sim_id  query_hash  \
# 0    Vir_N1_64_Ont_Opt_VWall   100037504
# 0    Vir_N1_32_Ont_Opt_VWall   100037504
# 1    Vir_N1_32_Ont_Opt_VWall  1001476692
# 1    Vir_N1_64_Ont_Opt_VWall  1001476692
# 2    Vir_N1_32_Ont_Opt_VWall  1003408745
# 0     Vir_N3_64_Ont_Opt_AWS3  1003408745
# 2    Vir_N1_64_Ont_Opt_VWall  1003408745
# 3    Vir_N1_32_Ont_Opt_VWall  1004308409
# 3    Vir_N1_64_Ont_Opt_VWall  1004308409
# 4    Vir_N1_64_Ont_Opt_VWall   100604759
# 4    Vir_N1_32_Ont_Opt_VWall   100604759
# 5    Vir_N1_32_Ont_Opt_VWall  1007016961
# 5    Vir_N1_64_Ont_Opt_VWall  1007016961
# 6    Vir_N1_32_Ont_Opt_VWall  1007519881
# 0     Vir_N3_64_Ont_Opt_AWS1  1007519881
# 6    Vir_N1_64_Ont_Opt_VWall  1007519881
# 7    Vir_N1_32_Ont_Opt_VWall  1009231253
# 7    Vir_N1_64_Ont_Opt_VWall  1009231253
# 8    Vir_N1_32_Ont_Opt_VWall   101367425
# 1     Vir_N3_64_Ont_Opt_AWS3   101367425
# 8    Vir_N1_64_Ont_Opt_VWall   101367425
# 9    Vir_N1_32_Ont_Opt_VWall  1014783775
# 9    Vir_N1_64_Ont_Opt_VWall  1014783775
# 10   Vir_N1_32_Ont_Opt_VWall  1015474493
# 10   Vir_N1_64_Ont_Opt_VWall  1015474493
# 2     Vir_N3_64_Ont_Opt_AWS3  1015474493
# 11   Vir_N1_64_Ont_Opt_VWall   103655936
# 11   Vir_N1_32_Ont_Opt_VWall   103655936
# 12   Vir_N1_64_Ont_Opt_VWall  1040494728
# 12   Vir_N1_32_Ont_Opt_VWall  1040494728
# ..                       ...         ...
# 73    Vir_N3_64_Ont_Opt_AWS1   965494036
# 149   Vir_N3_64_Ont_Opt_AWS3   965494036
# 816  Vir_N1_64_Ont_Opt_VWall   968373386
# 816  Vir_N1_32_Ont_Opt_VWall   968373386
# 817  Vir_N1_32_Ont_Opt_VWall    97037338
# 817  Vir_N1_64_Ont_Opt_VWall    97037338
# 818  Vir_N1_32_Ont_Opt_VWall   973202599
# 818  Vir_N1_64_Ont_Opt_VWall   973202599
# 819  Vir_N1_32_Ont_Opt_VWall    97508257
# 819  Vir_N1_64_Ont_Opt_VWall    97508257
# 820  Vir_N1_32_Ont_Opt_VWall    97777055
# 820  Vir_N1_64_Ont_Opt_VWall    97777055
# 150   Vir_N3_64_Ont_Opt_AWS3   977841011
# 821  Vir_N1_32_Ont_Opt_VWall   977841011
# 821  Vir_N1_64_Ont_Opt_VWall   977841011
# 822  Vir_N1_64_Ont_Opt_VWall   981003125
# 822  Vir_N1_32_Ont_Opt_VWall   981003125
# 823  Vir_N1_64_Ont_Opt_VWall   981041067
# 823  Vir_N1_32_Ont_Opt_VWall   981041067
# 824  Vir_N1_64_Ont_Opt_VWall   984902653
# 824  Vir_N1_32_Ont_Opt_VWall   984902653
# 74    Vir_N3_64_Ont_Opt_AWS1   984902653
# 825  Vir_N1_32_Ont_Opt_VWall   987665572
# 825  Vir_N1_64_Ont_Opt_VWall   987665572
# 826  Vir_N1_32_Ont_Opt_VWall   989691170
# 826  Vir_N1_64_Ont_Opt_VWall   989691170
# 827  Vir_N1_64_Ont_Opt_VWall   990387450
# 827  Vir_N1_32_Ont_Opt_VWall   990387450
# 828  Vir_N1_64_Ont_Opt_VWall   995250415
# 828  Vir_N1_32_Ont_Opt_VWall   995250415
#
#                                           first_result
# 0          http://purl.obolibrary.org/obo/ERO_0000229,
# 0          http://purl.obolibrary.org/obo/ERO_0000229,
# 1    1656^^http://www.w3.org/2001/XMLSchema#integer...
# 1    1656^^http://www.w3.org/2001/XMLSchema#integer...
# 2       278^^http://www.w3.org/2001/XMLSchema#integer,
# 0       278^^http://www.w3.org/2001/XMLSchema#integer,
# 2       278^^http://www.w3.org/2001/XMLSchema#integer,
# 3         0^^http://www.w3.org/2001/XMLSchema#integer,
# 3         0^^http://www.w3.org/2001/XMLSchema#integer,
# 4         0^^http://www.w3.org/2001/XMLSchema#integer,
# 4         0^^http://www.w3.org/2001/XMLSchema#integer,
# 5       http://purl.org/spar/biro/BibliographicRecord,
# 5       http://purl.org/spar/biro/BibliographicRecord,
# 6         0^^http://www.w3.org/2001/XMLSchema#integer,
# 0         0^^http://www.w3.org/2001/XMLSchema#integer,
# 6         0^^http://www.w3.org/2001/XMLSchema#integer,
# 7         0^^http://www.w3.org/2001/XMLSchema#integer,
# 7         0^^http://www.w3.org/2001/XMLSchema#integer,
# 8         0^^http://www.w3.org/2001/XMLSchema#integer,
# 1         0^^http://www.w3.org/2001/XMLSchema#integer,
# 8         0^^http://www.w3.org/2001/XMLSchema#integer,
# 9          http://purl.obolibrary.org/obo/ERO_0000229,
# 9          http://purl.obolibrary.org/obo/ERO_0000229,
# 10       17^^http://www.w3.org/2001/XMLSchema#integer,
# 10       17^^http://www.w3.org/2001/XMLSchema#integer,
# 2        17^^http://www.w3.org/2001/XMLSchema#integer,
# 11         http://purl.obolibrary.org/obo/ERO_0000230,
# 11         http://purl.obolibrary.org/obo/ERO_0000230,
# 12                                  Antigenix America,
# 12                                  Antigenix America,
# ..                                                 ...
# 73        0^^http://www.w3.org/2001/XMLSchema#integer,
# 149       0^^http://www.w3.org/2001/XMLSchema#integer,
# 816       0^^http://www.w3.org/2001/XMLSchema#integer,
# 816       0^^http://www.w3.org/2001/XMLSchema#integer,
# 817        http://purl.obolibrary.org/obo/ERO_0000230,
# 817        http://purl.obolibrary.org/obo/ERO_0000230,
# 818       0^^http://www.w3.org/2001/XMLSchema#integer,
# 818       0^^http://www.w3.org/2001/XMLSchema#integer,
# 819      13^^http://www.w3.org/2001/XMLSchema#integer,
# 819      13^^http://www.w3.org/2001/XMLSchema#integer,
# 820       0^^http://www.w3.org/2001/XMLSchema#integer,
# 820       0^^http://www.w3.org/2001/XMLSchema#integer,
# 150   http://rdf.ebi.ac.uk/terms/chembl#SmallMolecule,
# 821   http://rdf.ebi.ac.uk/terms/chembl#SmallMolecule,
# 821   http://rdf.ebi.ac.uk/terms/chembl#SmallMolecule,
# 822       0^^http://www.w3.org/2001/XMLSchema#integer,
# 822       0^^http://www.w3.org/2001/XMLSchema#integer,
# 823  133146^^http://www.w3.org/2001/XMLSchema#integer,
# 823  133146^^http://www.w3.org/2001/XMLSchema#integer,
# 824      14^^http://www.w3.org/2001/XMLSchema#integer,
# 824      14^^http://www.w3.org/2001/XMLSchema#integer,
# 74       14^^http://www.w3.org/2001/XMLSchema#integer,
# 825   http://rdf.ebi.ac.uk/terms/chembl#SmallMolecule,
# 825   http://rdf.ebi.ac.uk/terms/chembl#SmallMolecule,
# 826  http://ns.ontoforce.com/ontologies/gene/classe...
# 826  http://ns.ontoforce.com/ontologies/gene/classe...
# 827        http://purl.obolibrary.org/obo/ERO_0000229,
# 827        http://purl.obolibrary.org/obo/ERO_0000229,
# 828      11^^http://www.w3.org/2001/XMLSchema#integer,
# 828      11^^http://www.w3.org/2001/XMLSchema#integer,
#
# [2033 rows x 3 columns]

# %%
# Out:
#                       sim_id  query_hash  \
# 0    Vir_N1_64_Ont_Opt_VWall   100037504
# 0    Vir_N1_32_Ont_Opt_VWall   100037504
# 1    Vir_N1_32_Ont_Opt_VWall  1001476692
# 1    Vir_N1_64_Ont_Opt_VWall  1001476692
# 2    Vir_N1_32_Ont_Opt_VWall  1003408745
# 0     Vir_N3_64_Ont_Opt_AWS3  1003408745
# 2    Vir_N1_64_Ont_Opt_VWall  1003408745
# 3    Vir_N1_32_Ont_Opt_VWall  1004308409
# 3    Vir_N1_64_Ont_Opt_VWall  1004308409
# 4    Vir_N1_64_Ont_Opt_VWall   100604759
# 4    Vir_N1_32_Ont_Opt_VWall   100604759
# 5    Vir_N1_32_Ont_Opt_VWall  1007016961
# 5    Vir_N1_64_Ont_Opt_VWall  1007016961
# 6    Vir_N1_32_Ont_Opt_VWall  1007519881
# 0     Vir_N3_64_Ont_Opt_AWS1  1007519881
# 6    Vir_N1_64_Ont_Opt_VWall  1007519881
# 7    Vir_N1_32_Ont_Opt_VWall  1009231253
# 7    Vir_N1_64_Ont_Opt_VWall  1009231253
# 8    Vir_N1_32_Ont_Opt_VWall   101367425
# 1     Vir_N3_64_Ont_Opt_AWS3   101367425
# 8    Vir_N1_64_Ont_Opt_VWall   101367425
# 9    Vir_N1_32_Ont_Opt_VWall  1014783775
# 9    Vir_N1_64_Ont_Opt_VWall  1014783775
# 10   Vir_N1_32_Ont_Opt_VWall  1015474493
# 10   Vir_N1_64_Ont_Opt_VWall  1015474493
# 2     Vir_N3_64_Ont_Opt_AWS3  1015474493
# 11   Vir_N1_64_Ont_Opt_VWall   103655936
# 11   Vir_N1_32_Ont_Opt_VWall   103655936
# 12   Vir_N1_64_Ont_Opt_VWall  1040494728
# 12   Vir_N1_32_Ont_Opt_VWall  1040494728
# ..                       ...         ...
# 73    Vir_N3_64_Ont_Opt_AWS1   965494036
# 149   Vir_N3_64_Ont_Opt_AWS3   965494036
# 816  Vir_N1_64_Ont_Opt_VWall   968373386
# 816  Vir_N1_32_Ont_Opt_VWall   968373386
# 817  Vir_N1_32_Ont_Opt_VWall    97037338
# 817  Vir_N1_64_Ont_Opt_VWall    97037338
# 818  Vir_N1_32_Ont_Opt_VWall   973202599
# 818  Vir_N1_64_Ont_Opt_VWall   973202599
# 819  Vir_N1_32_Ont_Opt_VWall    97508257
# 819  Vir_N1_64_Ont_Opt_VWall    97508257
# 820  Vir_N1_32_Ont_Opt_VWall    97777055
# 820  Vir_N1_64_Ont_Opt_VWall    97777055
# 150   Vir_N3_64_Ont_Opt_AWS3   977841011
# 821  Vir_N1_32_Ont_Opt_VWall   977841011
# 821  Vir_N1_64_Ont_Opt_VWall   977841011
# 822  Vir_N1_64_Ont_Opt_VWall   981003125
# 822  Vir_N1_32_Ont_Opt_VWall   981003125
# 823  Vir_N1_64_Ont_Opt_VWall   981041067
# 823  Vir_N1_32_Ont_Opt_VWall   981041067
# 824  Vir_N1_64_Ont_Opt_VWall   984902653
# 824  Vir_N1_32_Ont_Opt_VWall   984902653
# 74    Vir_N3_64_Ont_Opt_AWS1   984902653
# 825  Vir_N1_32_Ont_Opt_VWall   987665572
# 825  Vir_N1_64_Ont_Opt_VWall   987665572
# 826  Vir_N1_32_Ont_Opt_VWall   989691170
# 826  Vir_N1_64_Ont_Opt_VWall   989691170
# 827  Vir_N1_64_Ont_Opt_VWall   990387450
# 827  Vir_N1_32_Ont_Opt_VWall   990387450
# 828  Vir_N1_64_Ont_Opt_VWall   995250415
# 828  Vir_N1_32_Ont_Opt_VWall   995250415
#
#                                           first_result
# 0          http://purl.obolibrary.org/obo/ERO_0000229,
# 0          http://purl.obolibrary.org/obo/ERO_0000229,
# 1    1656^^http://www.w3.org/2001/XMLSchema#integer...
# 1    1656^^http://www.w3.org/2001/XMLSchema#integer...
# 2       278^^http://www.w3.org/2001/XMLSchema#integer,
# 0       278^^http://www.w3.org/2001/XMLSchema#integer,
# 2       278^^http://www.w3.org/2001/XMLSchema#integer,
# 3         0^^http://www.w3.org/2001/XMLSchema#integer,
# 3         0^^http://www.w3.org/2001/XMLSchema#integer,
# 4         0^^http://www.w3.org/2001/XMLSchema#integer,
# 4         0^^http://www.w3.org/2001/XMLSchema#integer,
# 5       http://purl.org/spar/biro/BibliographicRecord,
# 5       http://purl.org/spar/biro/BibliographicRecord,
# 6         0^^http://www.w3.org/2001/XMLSchema#integer,
# 0         0^^http://www.w3.org/2001/XMLSchema#integer,
# 6         0^^http://www.w3.org/2001/XMLSchema#integer,
# 7         0^^http://www.w3.org/2001/XMLSchema#integer,
# 7         0^^http://www.w3.org/2001/XMLSchema#integer,
# 8         0^^http://www.w3.org/2001/XMLSchema#integer,
# 1         0^^http://www.w3.org/2001/XMLSchema#integer,
# 8         0^^http://www.w3.org/2001/XMLSchema#integer,
# 9          http://purl.obolibrary.org/obo/ERO_0000229,
# 9          http://purl.obolibrary.org/obo/ERO_0000229,
# 10       17^^http://www.w3.org/2001/XMLSchema#integer,
# 10       17^^http://www.w3.org/2001/XMLSchema#integer,
# 2        17^^http://www.w3.org/2001/XMLSchema#integer,
# 11         http://purl.obolibrary.org/obo/ERO_0000230,
# 11         http://purl.obolibrary.org/obo/ERO_0000230,
# 12                                  Antigenix America,
# 12                                  Antigenix America,
# ..                                                 ...
# 73        0^^http://www.w3.org/2001/XMLSchema#integer,
# 149       0^^http://www.w3.org/2001/XMLSchema#integer,
# 816       0^^http://www.w3.org/2001/XMLSchema#integer,
# 816       0^^http://www.w3.org/2001/XMLSchema#integer,
# 817        http://purl.obolibrary.org/obo/ERO_0000230,
# 817        http://purl.obolibrary.org/obo/ERO_0000230,
# 818       0^^http://www.w3.org/2001/XMLSchema#integer,
# 818       0^^http://www.w3.org/2001/XMLSchema#integer,
# 819      13^^http://www.w3.org/2001/XMLSchema#integer,
# 819      13^^http://www.w3.org/2001/XMLSchema#integer,
# 820       0^^http://www.w3.org/2001/XMLSchema#integer,
# 820       0^^http://www.w3.org/2001/XMLSchema#integer,
# 150   http://rdf.ebi.ac.uk/terms/chembl#SmallMolecule,
# 821   http://rdf.ebi.ac.uk/terms/chembl#SmallMolecule,
# 821   http://rdf.ebi.ac.uk/terms/chembl#SmallMolecule,
# 822       0^^http://www.w3.org/2001/XMLSchema#integer,
# 822       0^^http://www.w3.org/2001/XMLSchema#integer,
# 823  133146^^http://www.w3.org/2001/XMLSchema#integer,
# 823  133146^^http://www.w3.org/2001/XMLSchema#integer,
# 824      14^^http://www.w3.org/2001/XMLSchema#integer,
# 824      14^^http://www.w3.org/2001/XMLSchema#integer,
# 74       14^^http://www.w3.org/2001/XMLSchema#integer,
# 825   http://rdf.ebi.ac.uk/terms/chembl#SmallMolecule,
# 825   http://rdf.ebi.ac.uk/terms/chembl#SmallMolecule,
# 826  http://ns.ontoforce.com/ontologies/gene/classe...
# 826  http://ns.ontoforce.com/ontologies/gene/classe...
# 827        http://purl.obolibrary.org/obo/ERO_0000229,
# 827        http://purl.obolibrary.org/obo/ERO_0000229,
# 828      11^^http://www.w3.org/2001/XMLSchema#integer,
# 828      11^^http://www.w3.org/2001/XMLSchema#integer,
#
# [2033 rows x 3 columns]

# %% [markdown]
# # 3. Check for inconsistencies
#
# * Only one inconsistency found, and confirmed that it is not a count query

# %%
dfconsistent = df_all.groupby('query_hash', as_index=False).agg({'sim_id': np.size, 'first_result': pd.Series.nunique})

# %%
print(str(dfconsistent[dfconsistent['sim_id'] >1].shape[0]) + " queries occur in 2 or more sims")

dfconsistent[dfconsistent['first_result'] >1]
